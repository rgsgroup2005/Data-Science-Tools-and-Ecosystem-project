# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ### In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives:**
# * Some of the popular languages Data Scientists use
# * Some of the commonly used libraries used by Data Scientists
# * A few Data Science Tools
# * A few examples evaluating arithmetic expressions in Python
# * Converting minutes to hours

# %% [markdown]
# #### Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL
# 4. JAVA

# %% [markdown]
# #### Some of the commonly used libraries used by Data Scientists include:
# 1. Pandas
# 2. NumPy
# 3. PyTorch
# 4. TensorFlow

# %% [markdown]
# #### **Data Science Tools**
# -----------------------
# ##### Jupyter Notebook
# -----------------------
# ##### RStudio
# -----------------------
# ##### Apache Spark

# %% [markdown]
# ### Below are a few examples evaluating arithmetic expressions in Python
# * **Addition:** '12+18'
# * **Multiplication:** '(12 * 8)'
# * **Division:** '24 / 2'

# %%
# This is a simple arithmetic expression to multiply then add integers
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 nminutes to hours by dividing by 60
200 / 60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# Frank Pasquale Cusumano
